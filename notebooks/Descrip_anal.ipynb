# %%
import pandas as pd
import sys
sys.path.insert(0, '/10 A KAI 2/week 1/Stock_Price_Analysis/')

# %%
from src.Descrip_anal import Descriptives

# %%
df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# ...

# %%
des = Descriptives(df)

# %%
des.get_headline_lengths()
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# ...

# %%
des.get_top_ten_headline_len()
# Out:
#                                                  headline  \
# 701748  JinkoSolar Tiger Pro Series Receives World's F...
# 238137  Check Point® Software Technologies Ltd. (NASDA...
# 39028   Shares of several financial services companies...
# 140048  Shares of several financial services companies...
# 140381  Shares of several financial services companies...
# 172392  Shares of several financial services companies...
# 187727  Shares of several financial services companies...
# 197884  Shares of several financial services companies...
# 301325  Shares of several financial services companies...
# 316938  Shares of several financial services companies...
#
#                                                       url          publisher  \
# 701748  https://www.benzinga.com/news/20/06/16166972/j...      Charles Gross
# 238137  https://www.benzinga.com/news/20/01/15132679/c...      Charles Gross
# 39028   https://www.benzinga.com/wiim/20/05/16032873/s...  Benzinga Newsdesk
# ...

# %%
res = des.count_healine_by_publisher()

# %%
res.head(20)
# Out:
#               publisher  publisher_count
# 686       Paul Quintaro           228373
# 532          Lisa Levin           186979
# 96    Benzinga Newsdesk           150484
# 169       Charles Gross            96732
# 622       Monica Gerson            82380
# 275        Eddie Staley            57254
# 353          Hal Lindon            49047
# 270       ETF Professor            28489
# 478          Juan Lopez            28438
# 98       Benzinga Staff            28114
# 907          Vick Meyer            24826
# 1033          webmaster            20313
# 111   Benzinga_Newsdesk            19410
# 942               Zacks            19390
# 418      Jayson Derrick            19050
# 34        Allie Wickman            18317
# 777    Shanthi Rexaline            16640
# 208         Craig Jones            16221
# 922        Wayne Duggan            12897
# 639          Nelson Hem            12590

# %%
res1 = des.format_date_time()
# Out:
# d:\10 A KAI 2/week 1/Stock_Price_Analysis\src\Descrip_anal.py:17: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   self.df['date'] = pd.to_datetime(self.df['date'], format='mixed')

# %%
res1.tail(40)
# Out:
#                                                   headline  \
# 1407288  China Zenix Auto Regains Compliance with NYSE ...
# 1407289  China Zenix, JAC Form Strategic Partnership To...
# 1407290  China Zenix Auto Int'l Reports Q2 Loss $0.01, ...
# 1407291  Tuesday, Wednesday's Economic Conditions And M...
# 1407292  Top 4 NYSE Stocks In The Auto Parts Industry W...
# 1407293  China Zenix Auto Q1 EPS $0.00, Revenue $116.5M...
# 1407294  China Zenix Auto Reports Q4 Loss/ADS $(0.04); ...
# 1407295  China Zenix Auto Wins Supply Contract With Car...
# 1407296                              Morning Market Movers
# 1407297  China Zenix Auto Awarded Supply Contract With FAW
# 1407298  5 Consumer Goods Stocks With The Lowest PEG Ratio
# 1407299           Earnings Scheduled For November 13, 2014
# 1407300  5 Consumer Goods Stocks With The Lowest PEG Ratio
# 1407301  Zenix Auto Developing Aluminum Wheel For Yuton...
# 1407302  China Zenix Auto International Announces Crowe...
# ...

# %%
df
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# ...
